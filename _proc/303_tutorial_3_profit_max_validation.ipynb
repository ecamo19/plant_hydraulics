# %% [raw]
# ---
# output-file: tutorial_3_profit_max_validation.html
# title: 'Tutorial 3: Validating profix-max model vrs Sperry et al 2017 results'
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# [Sperry JS, Venturas MD, Anderegg WRL, Mencucinni M, Mackay DS, Wang Y, Love DM (2017) Predicting stomatal responses to the environment from the optimization of photosynthetic gain and hydraulic cost. Plant Cell and Environment 40: 816-830](https://sperry.biology.utah.edu/publications/Sperry_et_al_2017_PCE.pdf)
