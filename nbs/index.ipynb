# %%
#| hide
from plant_hydraulics.core import *

# %% [markdown]
# # plant_hydraulics
#
# >

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install plant_hydraulics in Development mode

# %% [markdown]
# ```sh
# # make sure plant_hydraulics package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to plant_hydraulics
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/ecamo19/plant_hydraulics.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c ecamo19 plant_hydraulics
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install plant_hydraulics
# ```
#
#
# [repo]: https://github.com/ecamo19/plant_hydraulics
# [docs]: https://ecamo19.github.io/plant_hydraulics/
# [pypi]: https://pypi.org/project/plant_hydraulics/
# [conda]: https://anaconda.org/ecamo19/plant_hydraulics

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/ecamo19/plant_hydraulics
# [docs]: https://ecamo19.github.io/plant_hydraulics/
# [pypi]: https://pypi.org/project/plant_hydraulics/
# [conda]: https://anaconda.org/ecamo19/plant_hydraulics

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
